# %% [markdown]
# # Discrete Math 2: Lecture 2 Assignment
# ##### by Jade Shaira M. de Paz
# ##### BS Computer Science - 1

# %% [markdown]
# Task 1:
# Consider the following experiment:
#
# 1. The experiment consists of $n$ identical trials.
# 2. The outcome of each trial falls into one of $k$ classes or cells.
# 3. The probability that the outcome of a single trial falls into cell $i$, is $p_i,i = 1,2,...,k$ and remains the same from trial to trial. Notice that $p_1+p_2+p_3+···+p_k =1.$
# 4. The trials are independent.
# 5. The random variables of interest are $Y_1 , Y_2 , . . . , Y_k$, where $Y_i$ equals the number of trials for which the outcome falls into cell $i$. Notice that $Y_1 +Y_2 +Y_3 +···+Y_k =n$.
# 6. The joint probability distribution $P(y) = \frac{n!}{y_1!y_2!y_3!...y_n!} P_1^{y_1} P_2^{y_2} P_3^{y_3}....P_n^{y_n}$
#
# Question 1: Show that the expected value $E[y] = \Sigma y \cdotp P(y) = n \cdot p_i$
#
# Question 2: Given the following data
# \begin{gather}
# \begin{bmatrix}
# \begin{array}{c|c}
# Age & Proportion \\
# 18-24 & 0.18 \\
# 25-34 & 0.23 \\
# 35-44 & 0.16 \\
# 45-64 & 0.27 \\
# 65-100 & 0.16 \\
# \end{array}
# \end{bmatrix}
# \end{gather}
#
# If 500 adults are sampled  randomly, find the probability rhat the sample contains 100 person between 18 and 24, 200 between, 200 between the ages of 25 and 34, and 200 between the ages of 45 and 64.. What is the expected value for to obtain a person in the 65 and above?

# %% [markdown]
# ### Task 1 Answers:
# #### Question 1:
#
# To show that the expected value $E[y] = \sum y \cdot P(y) = n \cdot p_i$, let's calculate $E[Y_i]$, the expected value of $Y_i$.
#
# The expected value of a random variable $Y_i$ is defined as:
#
# $$
# E[Y_i] = \sum_{y_i} y_i \cdot P(Y_i = y_i)
# $$
#
# Given that $Y_i$ follows a binomial distribution with parameters $n$ and $p_i$, the probability mass function $P(Y_i = y_i)$ is:
#
# $$
# P(Y_i = y_i) = \binom{n}{y_i} p_i^{y_i} (1 - p_i)^{n - y_i}
# $$
#
# Substituting this into the formula for the expected value:
#
# $$
# E[Y_i] = \sum_{y_i} y_i \cdot \binom{n}{y_i} p_i^{y_i} (1 - p_i)^{n - y_i}
# $$
#
# This is the expected value of a binomial distribution, which is $n \cdot p_i$. Therefore, $E[Y_i] = n \cdot p_i$.
#
# Now, since $Y_1, Y_2, \ldots, Y_k$ are independent random variables, the expected value of their sum is the sum of their expected values:
#
# $$
# E[Y] = E[Y_1 + Y_2 + \ldots + Y_k] = E[Y_1] + E[Y_2] + \ldots + E[Y_k]
# $$
#
# Substituting $E[Y_i] = n \cdot p_i$ for each $Y_i$:
#
# $$
# E[Y] = n \cdot p_1 + n \cdot p_2 + \ldots + n \cdot p_k = n \cdot (p_1 + p_2 + \ldots + p_k) = n \cdot 1 = n
# $$
#
# Thus, the expected value $E[Y] = n \cdot p_i$.
#
# ### Question 2:
#
# Given the data:
#
#
# \begin{align*}
# \text{Age} & \quad \text{Proportion} \\
# 18-24 & \quad 0.18 \\
# 25-34 & \quad 0.23 \\
# 35-44 & \quad 0.16 \\
# 45-64 & \quad 0.27 \\
# 65-100 & \quad 0.16 \\
# \end{align*}
#
#
# If 500 adults are sampled randomly, we want to find the probability that the sample contains 100 persons between 18 and 24, 200 between 25 and 34, and 200 between 45 and 64.
#
# We use the multinomial probability formula:
#
# $$
# P(y_1, y_2, y_3, y_4, y_5) = \frac{n!}{y_1!y_2!y_3!y_4!y_5!} p_1^{y_1} p_2^{y_2} p_3^{y_3} p_4^{y_4} p_5^{y_5}
# $$
#
# where $n$ is the total sample size (500 in this case), $y_i$ is the number of individuals in the $i$th age group, and $p_i$ is the proportion of individuals in the $i$th age group.
#
# For the expected value to obtain a person aged 65 and above, we simply multiply the total sample size by the proportion of individuals in that age group:
#
# $$
# \text{Expected value for 65 and above} = 500 \times 0.16
# $$
# $$
# E[y_5] = n \cdot p_5 = 500 \cdot 0.16 = 80
# $$

# %% [markdown]
# Task 2: Consider the following experiment:
#
# 1. The experiment consists of a fixed number, $n$, of identical trials.
# 2. Each trial results in one of two outcomes: success, $S$, or failure, $F$.
# 3. The probability of success on a single trial is equal to some value $p$ and remains the same from trial to trial. The probability of a failure is equal to q = $(1 − p)$.
# 4. The trials are independent.
# 5. The random variable of interest is $Y$ , the number of successes observed during the $n$ trials.
#
# Question 1: From the following steps shown above, derive the probability distribution of the experiment.
#
# Question 2: Show that the expectation of this probability distribution is $E[y] = \Sigma y \cdotp P(y) = np$.
#
# Question 3: Experience has shown that 30% of all persons afflicted by a certain illness recover. A drug company has developed a new medication. Ten people with the illness were selected at random and received the medication; nine recovered shortly thereafter. Suppose that the medication was absolutely worthless. What is the probability that at least nine of ten receiving the medication will recover?
#
# Question 4: Suppose that a lot of 5000 electrical fuses contains 5% defectives. If a sample of 5 fuses is tested, find the probability of observing at least one defective.

# %% [markdown]
# ### Task 2 Answers:
# #### Question 1:
#
# The probability distribution of the experiment can be derived as follows:
#
# Since each trial results in either success ($S$) or failure ($F$), and the trials are independent, the probability of observing $y$ successes in $n$ trials follows a binomial distribution.
#
# The probability of observing exactly $y$ successes in $n$ trials is given by the binomial probability formula:
#
# $$[ P(Y=y) = \binom{n}{y} p^y q^{n-y} ]$$
#
# where:
# - $p$ is the probability of success on a single trial.
# - $q = (1 - p)$ is the probability of failure on a single trial.
# - $n$ is the total number of trials.
# - $y$ is the number of successes observed.
#
# This formula represents the probability distribution of the experiment.
#
# #### Question 2:
#
# To show that the expectation of this probability distribution is $E[y] = \sum y \cdot P(y) = np$:
#
# The expectation, $E[y]$, of a binomial distribution is given by the formula:
#
# $$[ E[y] = \sum_{y=0}^{n} y \cdot P(Y=y) ]$$
#
# Substituting the binomial probability formula, we get:
#
# $$[ E[y] = \sum_{y=0}^{n} y \cdot \binom{n}{y} p^y q^{n-y} ]$$
#
# This sum simplifies to $ np $, which proves that $E[y] = np$.
#
# #### Question 3:
#
# Given the experiment setup where the medication is worthless, the probability of recovery remains at 30%. We are interested in the probability of at least 9 out of 10 people recovering. Let $( Y $) be the number of recoveries.
#
# We need to find $$( P(Y \geq 9) )$$, which is:
#
# $$[ P(Y \geq 9) = P(Y = 9) + P(Y = 10) ]$$
#
# First, compute $$( P(Y = 9) )$$ and $$( P(Y = 10) )$$:
#
# $$[ P(Y = 9) = \binom{10}{9} (0.3)^9 (0.7)^1 = 10 \cdot (0.3)^9 \cdot (0.7) ]$$
# $$[ P(Y = 10) = \binom{10}{10} (0.3)^{10} (0.7)^0 = 1 \cdot (0.3)^{10} ]$$
#
# Calculate each term:
#
# $$[ P(Y = 9) = 10 \cdot (0.3)^9 \cdot 0.7 \approx 10 \cdot 0.000019683 \cdot 0.7 \approx 0.00013778 ]$$
# $$[ P(Y = 10) = (0.3)^{10} \approx 0.0000059049 ]$$
#
# Thus:
#
# $$[ P(Y \geq 9) = 0.00013778 + 0.0000059049 \approx 0.00014368 ]$$
#
# #### Question 4:
#
# The lot contains 5000 fuses with 5% defectives, so $( p = 0.05 )$. We test 5 fuses, so $( n = 5 )$.
#
# Let $( Y )$ be the number of defective fuses in the sample. We need $( P(Y \geq 1) )$, which can be found using the complement rule:
#
# $$[ P(Y \geq 1) = 1 - P(Y = 0) ]$$
#
# First, compute $( P(Y = 0) )$:
#
# $$[ P(Y = 0) = \binom{5}{0} (0.05)^0 (0.95)^5 = (0.95)^5 ]$$
#
# Calculate:
#
# $$[ (0.95)^5 \approx 0.77378 ]$$
#
# Therefore:
#
# $$[ P(Y \geq 1) = 1 - 0.77378 \approx 0.22622 ]$$
#
# So, the probability of observing at least one defective fuse in a sample of 5 is approximately $( 0.22622 )$ or 22.62%.

# %% [markdown]
# Task 3: Consider a probility distribution of $p(y) = \frac{\lambda^y}{y!} e^{-\lambda}$.
#
# Question 1: Find a general formula for the expected value of this distribution.
#
# Question 2: A certain type of tree has seedlings randomly dispersed in a large area, with the mean density of seedlings being approximately five per square yard. If a forester randomly locates ten 1-square-yard sampling regions in the area, find the probability that none of the regions will contain seedlings.

# %% [markdown]
# ### Task 3 Answers:
# #### Question 1:
#
# For a Poisson random variable $(Y)$ with parameter $(\lambda)$, the expected value (mean) $(E[Y])$ can be derived from the definition of the Poisson distribution:
#
# $$[ p(y) = \frac{\lambda^y}{y!} e^{-\lambda}, \quad y = 0, 1, 2, \ldots ]$$
#
# To find the expected value $(E[Y]$), we use the definition of expectation:
#
# $$[ E[Y] = \sum_{y=0}^{\infty} y \cdot p(y) ]$$
#
# Plugging in the probability mass function:
#
# $$[ E[Y] = \sum_{y=0}^{\infty} y \cdot \frac{\lambda^y}{y!} e^{-\lambda} ]$$
#
# We can rewrite $( y \cdot \frac{\lambda^y}{y!} )$ as $( \lambda \cdot \frac{\lambda^{y-1}}{(y-1)!} )$. This shift in the index simplifies the summation. Let $( z = y - 1 )$:
#
# $$[ E[Y] = \sum_{y=0}^{\infty} y \cdot \frac{\lambda^y}{y!} e^{-\lambda} = \lambda e^{-\lambda} \sum_{y=1}^{\infty} \frac{\lambda^{y-1}}{(y-1)!} ]$$
#
# By changing the index of summation from $( y )$ to $( z )$:
#
# $$[ E[Y] = \lambda e^{-\lambda} \sum_{z=0}^{\infty} \frac{\lambda^z}{z!} ]$$
#
# Notice that the sum $( \sum_{z=0}^{\infty} \frac{\lambda^z}{z!} )$ is the Taylor series expansion of $( e^{\lambda} )$:
#
# $$[ \sum_{z=0}^{\infty} \frac{\lambda^z}{z!} = e^{\lambda} ]$$
#
# Thus:
#
# $$[ E[Y] = \lambda e^{-\lambda} \cdot e^{\lambda} = \lambda ]$$
#
# So, the expected value of a Poisson distribution with parameter $(\lambda)$ is:
#
# $$[ \boxed{E[Y] = \lambda} ]$$
#
# #### Question 2:
#
# In this problem, we are given that the mean density of seedlings is \(\lambda = 5\) seedlings per square yard. A forester randomly locates ten 1-square-yard sampling regions. We are asked to find the probability that none of these regions will contain seedlings.
#
# Since the presence of seedlings in different regions is independent, we can model the number of seedlings in each 1-square-yard region as a Poisson random variable with $(\lambda = 5)$.
#
# The probability that a single region contains zero seedlings (using the Poisson distribution formula) is:
#
# $$[ P(Y = 0) = \frac{\lambda^0}{0!} e^{-\lambda} = e^{-5} ]$$
#
# Since there are ten independent regions, and we want the probability that none of these ten regions contain seedlings, we raise the single-region probability to the tenth power:
#
# $$[ P(\text{none of the regions contain seedlings}) = (e^{-5})^{10} = e^{-50} ]$$
#
# Thus, the probability that none of the ten 1-square-yard sampling regions will contain seedlings is:
#
# $$[ \boxed{e^{-50}} ]$$
